# %% [markdown]
# <a href="https://colab.research.google.com/github/AadityaAdh/Standardization_Normalization/blob/main/Standardization_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #firstly lets understand the concepts

# %%
data=np.random.randint(100,200,300)
print(data)
# Out:
# [102 184 139 141 101 105 123 121 128 198 153 192 173 184 170 116 139 158
#  179 105 132 179 199 122 172 158 155 180 125 190 169 137 100 166 165 135
#  152 199 121 159 161 118 123 142 162 103 170 134 136 199 184 160 119 150
#  108 109 135 133 171 175 136 149 175 195 161 139 113 135 188 135 166 185
#  106 146 104 107 196 141 178 175 117 111 106 131 177 127 138 167 172 127
#  137 173 147 153 117 107 149 112 194 182 104 174 109 122 136 112 180 191
#  150 121 115 195 119 137 134 103 101 163 190 132 162 167 139 190 120 135
#  148 141 129 181 121 157 198 120 157 155 178 163 167 111 133 105 119 115
#  126 134 109 132 122 121 151 120 173 104 141 100 183 155 198 122 145 188
#  148 106 125 175 145 166 150 172 196 152 173 175 119 122 190 110 138 126
#  130 144 187 151 169 150 129 145 153 141 196 114 178 190 148 192 132 180
#  141 179 116 173 101 174 120 135 136 195 176 131 154 158 100 115 184 132
#  197 136 109 139 187 107 140 149 171 100 164 174 169 144 109 160 160 140
#  179 112 151 178 119 187 175 171 106 160 119 113 134 153 196 116 114 174
#  190 132 199 130 122 148 172 135 118 156 159 183 122 151 199 195 106 108
#  186 187 186 183 174 109 100 148 109 192 179 161 174 152 172 190 140 112
#  140 172 190 124 160 139 157 152 157 140 143 106]

# %%
#lets plot histogram of this
plt.hist(data, bins=10, edgecolor='black')
plt.show()

# %% [markdown]
# lets subtract 50 from the data and plot the histogram

# %%
data1=data-50
data1
# Out:
# array([ 52, 134,  89,  91,  51,  55,  73,  71,  78, 148, 103, 142, 123,
#        134, 120,  66,  89, 108, 129,  55,  82, 129, 149,  72, 122, 108,
#        105, 130,  75, 140, 119,  87,  50, 116, 115,  85, 102, 149,  71,
#        109, 111,  68,  73,  92, 112,  53, 120,  84,  86, 149, 134, 110,
#         69, 100,  58,  59,  85,  83, 121, 125,  86,  99, 125, 145, 111,
#         89,  63,  85, 138,  85, 116, 135,  56,  96,  54,  57, 146,  91,
#        128, 125,  67,  61,  56,  81, 127,  77,  88, 117, 122,  77,  87,
#        123,  97, 103,  67,  57,  99,  62, 144, 132,  54, 124,  59,  72,
#         86,  62, 130, 141, 100,  71,  65, 145,  69,  87,  84,  53,  51,
#        113, 140,  82, 112, 117,  89, 140,  70,  85,  98,  91,  79, 131,
#         71, 107, 148,  70, 107, 105, 128, 113, 117,  61,  83,  55,  69,
#         65,  76,  84,  59,  82,  72,  71, 101,  70, 123,  54,  91,  50,
#        133, 105, 148,  72,  95, 138,  98,  56,  75, 125,  95, 116, 100,
#        122, 146, 102, 123, 125,  69,  72, 140,  60,  88,  76,  80,  94,
#        137, 101, 119, 100,  79,  95, 103,  91, 146,  64, 128, 140,  98,
#        142,  82, 130,  91, 129,  66, 123,  51, 124,  70,  85,  86, 145,
#        126,  81, 104, 108,  50,  65, 134,  82, 147,  86,  59,  89, 137,
#         57,  90,  99, 121,  50, 114, 124, 119,  94,  59, 110, 110,  90,
#        129,  62, 101, 128,  69, 137, 125, 121,  56, 110,  69,  63,  84,
#        103, 146,  66,  64, 124, 140,  82, 149,  80,  72,  98, 122,  85,
#         68, 106, 109, 133,  72, 101, 149, 145,  56,  58, 136, 137, 136,
#        133, 124,  59,  50,  98,  59, 142, 129, 111, 124, 102, 122, 140,
#         90,  62,  90, 122, 140,  74, 110,  89, 107, 102, 107,  90,  93,
#         56])

# %%
plt.hist(data1,bins=10,edgecolor='black')
plt.show()

# %% [markdown]
# #so we can tell it has been shifted to the left

# %% [markdown]
# now lets again divide it by lets say 50

# %%
data2=data1/50 #data2=data-50/50
plt.hist(data2,bins=10,edgecolor='black')
plt.show()

# %% [markdown]
# #so it has shrinked the histogram
# or histogram ko width or data ko range nai ghataidyo
#
# for visualization
#
# https://www.youtube.com/watch?v=sxEqtjLC0aM

# %% [markdown]
# #Feature scaling
#
# to convert into smaller ranges
#
# if you have x in range of 1-100
# if you have y in range of 1-10
#
# now you want to convet both of this in similar range like 0-1 or others it is called as scaling
# it prevents x to be significantly dominant over y
#
# so example
# the knn algorithm is based on distance measurement
#
# so lets say we have two points in age as 20,30
# and salary is 100000 and 200000
# now lets calculate the distances

# %%
#here data point is(20,100000) and (30,200000)
#lets calculate distance between these points

# %%
age1=20
age2=30

# %%
salary1=100000
salary2=200000

# %%
dist=(((age2-age1)**2)+((salary2-salary1)**2))**0.5
dist
# Out:
# 100000.0005

# %%
#lets put age as 0
age1=0
age2=0
dist=(((age2-age1)**2)+((salary2-salary1)**2))**0.5
dist
# Out:
# 100000.0

# %% [markdown]
# so it seems there is no point of using age
# but age is also a significant paramenter
# so both of them should be scaled to same scales so that duitai lai yeutai(balance/scale) taraju bata herna sakyos
#
# age lai no of years bata nikalinxa
# salary lai money ko terms ma
# money 1 ni hua sakxa 1000000..... ni huna sakxa
# duita ko unit of measurement nai mildaina
# so duitai lai yeutai scale le napyo vanae balla comparison hunxa

# %% [markdown]
# #feature scaling types
#
#             feature scaling
#                 |
#                 |
#                 |
#                / \
#               /   \
#              /     \
#             /       \
#            /         \
#       standarization normalization

# %% [markdown]
# #Standarization
#
# yo (x-mean)/sd
# gare ra garni lai standarization vanxa
#
# it is also known as z-score Normalization
# the mean of the result dataa will have
#
#     mean=0
#     sd=1
#
#
# which means mean of data is 0 and if the data isnt deviated highly the most data will be in the range of -1 to 1
# but it wont always be the case
# -1 to +1 nai hunxa vanni fixed hudaina yesma
#
# data katti ko spread xa standard deviation describes about it
#
# note:yo formula laudaima data normal distribution ko curve banauxa vanni chai haina
# curve ta mathi vanya jasto shift ra shrink huni matrai ho

# %%
from matplotlib.image import imread

# Load the image from the specified path
image_path = "/content/standarization.png"
image = imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %% [markdown]
# #coding example of standarization

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#lets generate age and salary randomly and make one by stacking

# %%
#generate age
age=np.random.randint(20,70,50)
age
# Out:
# array([61, 56, 24, 23, 38, 20, 33, 22, 21, 42, 25, 67, 41, 29, 67, 69, 31,
#        48, 35, 24, 22, 52, 52, 41, 61, 28, 22, 65, 57, 51, 62, 32, 22, 38,
#        53, 68, 61, 30, 68, 26, 36, 63, 54, 36, 62, 49, 42, 56, 58, 38])

# %%
salary=np.random.randint(20000,70000,50)
salary
# Out:
# array([44874, 40414, 29396, 47139, 52880, 66735, 25314, 31821, 68960,
#        42321, 66865, 31942, 31352, 47045, 42189, 21856, 35843, 51258,
#        37699, 35257, 29664, 63333, 61096, 58049, 58746, 43210, 39341,
#        41328, 40531, 42441, 58921, 27017, 35252, 39969, 59653, 66065,
#        31425, 49194, 44169, 20528, 24487, 51857, 58044, 34588, 54068,
#        20478, 46110, 39036, 24208, 57902])

# %%
#stacking them up to make one dataset
data=np.stack((age,salary),axis=1)
data
# Out:
# array([[   61, 44874],
#        [   56, 40414],
#        [   24, 29396],
#        [   23, 47139],
#        [   38, 52880],
#        [   20, 66735],
#        [   33, 25314],
#        [   22, 31821],
#        [   21, 68960],
#        [   42, 42321],
#        [   25, 66865],
#        [   67, 31942],
#        [   41, 31352],
#        [   29, 47045],
#        [   67, 42189],
#        [   69, 21856],
#        [   31, 35843],
#        [   48, 51258],
#        [   35, 37699],
#        [   24, 35257],
#        [   22, 29664],
#        [   52, 63333],
#        [   52, 61096],
#        [   41, 58049],
#        [   61, 58746],
#        [   28, 43210],
#        [   22, 39341],
#        [   65, 41328],
#        [   57, 40531],
#        [   51, 42441],
#        [   62, 58921],
#        [   32, 27017],
#        [   22, 35252],
#        [   38, 39969],
#        [   53, 59653],
#        [   68, 66065],
#        [   61, 31425],
#        [   30, 49194],
#        [   68, 44169],
#        [   26, 20528],
#        [   36, 24487],
#        [   63, 51857],
#        [   54, 58044],
#        [   36, 34588],
#        [   62, 54068],
#        [   49, 20478],
#        [   42, 46110],
#        [   56, 39036],
#        [   58, 24208],
#        [   38, 57902]])

# %%
#concat garya vayae duitai lai yeuati ma hunthyo
con=np.concatenate((age,salary))
con
# Out:
# array([   61,    56,    24,    23,    38,    20,    33,    22,    21,
#           42,    25,    67,    41,    29,    67,    69,    31,    48,
#           35,    24,    22,    52,    52,    41,    61,    28,    22,
#           65,    57,    51,    62,    32,    22,    38,    53,    68,
#           61,    30,    68,    26,    36,    63,    54,    36,    62,
#           49,    42,    56,    58,    38, 44874, 40414, 29396, 47139,
#        52880, 66735, 25314, 31821, 68960, 42321, 66865, 31942, 31352,
#        47045, 42189, 21856, 35843, 51258, 37699, 35257, 29664, 63333,
#        61096, 58049, 58746, 43210, 39341, 41328, 40531, 42441, 58921,
#        27017, 35252, 39969, 59653, 66065, 31425, 49194, 44169, 20528,
#        24487, 51857, 58044, 34588, 54068, 20478, 46110, 39036, 24208,
#        57902])

# %%
#lets plot histogram of the datas
#histogram of age before scaling

plt.hist(age,bins=10,edgecolor='black')
plt.show()

# %%
plt.hist(salary,bins=10,edgecolor='black')
plt.show()

# %%
#now lets do standarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(data)
# Out:
# StandardScaler()

# %% [markdown]
# #salar.fit
# yo vanya chai data ko barae ma pada vanya
#
# age vanni column ko mean kati sd kati maximum valie kati min kati etc
#
# not just age column but for all given column

# %%
scaler.mean_
# Out:
# array([   43.62, 43437.4 ])

# %% [markdown]
# duita column xa tei so duita  column ma vako data ko mean
#
# we can verify this as we seperatly have age,salary column in age numpy array

# %%
#yo muni ko line error aaye ra garya matrai ho
age1=age.reshape(-1, 1)
scaler.fit(age1)

scaler.mean_
#so it is also 41
# Out:
# array([43.62])

# %%
scaler.fit(data)
scaler.mean_
# Out:
# array([   43.62, 43437.4 ])

# %%
scaled=scaler.transform(data)
scaled
# Out:
# array([[ 1.09406544,  0.10764411],
#        [ 0.77931704, -0.22654267],
#        [-1.23507272, -1.05211887],
#        [-1.2980224 ,  0.27736004],
#        [-0.3537772 ,  0.70753185],
#        [-1.48687144,  1.74568381],
#        [-0.6685256 , -1.35798219],
#        [-1.36097208, -0.87041418],
#        [-1.42392176,  1.91240254],
#        [-0.10197848, -0.0836516 ],
#        [-1.17212304,  1.75542468],
#        [ 1.47176352, -0.86134768],
#        [-0.16492816, -0.90555624],
#        [-0.92032432,  0.27031664],
#        [ 1.47176352, -0.09354232],
#        [ 1.59766288, -1.61708934],
#        [-0.79442496, -0.56904664],
#        [ 0.2757196 ,  0.58599576],
#        [-0.54262624, -0.42997699],
#        [-1.23507272, -0.61295549],
#        [-1.36097208, -1.03203769],
#        [ 0.52751832,  1.49077273],
#        [ 0.52751832,  1.32315483],
#        [-0.16492816,  1.09484383],
#        [ 1.09406544,  1.14706988],
#        [-0.983274  , -0.01703903],
#        [-1.36097208, -0.30694231],
#        [ 1.34586416, -0.15805686],
#        [ 0.84226672, -0.21777588],
#        [ 0.46456864, -0.07466002],
#        [ 1.15701512,  1.16018258],
#        [-0.73147528, -1.23037679],
#        [-1.36097208, -0.61333014],
#        [-0.3537772 , -0.25988641],
#        [ 0.590468  ,  1.21503118],
#        [ 1.5347132 ,  1.69548086],
#        [ 1.09406544, -0.90008637],
#        [-0.85737464,  0.43134071],
#        [ 1.5347132 ,  0.05481862],
#        [-1.10917336, -1.71659607],
#        [-0.47967656, -1.41994911],
#        [ 1.2199648 ,  0.63087869],
#        [ 0.65341768,  1.09446918],
#        [-0.47967656, -0.66308351],
#        [ 1.15701512,  0.79654841],
#        [ 0.33866928, -1.72034256],
#        [-0.10197848,  0.2002573 ],
#        [ 0.77931704, -0.32979589],
#        [ 0.9052164 , -1.44085452],
#        [-0.3537772 ,  1.08382915]])

# %%
#dherai deviate na vako data thyo ra 1,-1 kai bich ma xa
#note mean nikalyo vanae 0 nai aauxa ra sd chai 1

# %%
#lets see if the data stucture has been changed or not
plt.subplot(1,2,1)
plt.scatter(data[:,0],data[:,1])
plt.title('before scaling')
plt.subplot(1,2,2)
plt.scatter(scaled[:,0],scaled[:,1])
plt.title('after scaling')
plt.show()

# %% [markdown]
# so we can see that there is no change in data patterns too
#
# the only thing it did was to bring them both on a same range or scales

# %% [markdown]
# #propability distrubution
#
#
# yellai histogram jastai samjhini but with infinite bins
# aani y axis ma chai probaability hunxa

# %%
from matplotlib.image import imread
image_path = "/content/pdf.png"
image = imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %% [markdown]
# given figure ma random experiment garda your x data less than or different range ma parni probability herna milxa yesto le
# probability density function for continious  random variable and mass function for discrete random variable

# %%
#lets do for outliers what does it do

# %% [markdown]
# #Outliers in standarization
#
# yeuta duita outliers banama aani tellai last ma haldim

# %%
outliers=np.array([[100,1000000],[110,1500000]])
outliers_data=np.append(data,outliers,axis=0)
outliers_data
# Out:
# array([[     61,   44874],
#        [     56,   40414],
#        [     24,   29396],
#        [     23,   47139],
#        [     38,   52880],
#        [     20,   66735],
#        [     33,   25314],
#        [     22,   31821],
#        [     21,   68960],
#        [     42,   42321],
#        [     25,   66865],
#        [     67,   31942],
#        [     41,   31352],
#        [     29,   47045],
#        [     67,   42189],
#        [     69,   21856],
#        [     31,   35843],
#        [     48,   51258],
#        [     35,   37699],
#        [     24,   35257],
#        [     22,   29664],
#        [     52,   63333],
#        [     52,   61096],
#        [     41,   58049],
#        [     61,   58746],
#        [     28,   43210],
#        [     22,   39341],
#        [     65,   41328],
#        [     57,   40531],
#        [     51,   42441],
#        [     62,   58921],
#        [     32,   27017],
#        [     22,   35252],
#        [     38,   39969],
#        [     53,   59653],
#        [     68,   66065],
#        [     61,   31425],
#        [     30,   49194],
#        [     68,   44169],
#        [     26,   20528],
#        [     36,   24487],
#        [     63,   51857],
#        [     54,   58044],
#        [     36,   34588],
#        [     62,   54068],
#        [     49,   20478],
#        [     42,   46110],
#        [     56,   39036],
#        [     58,   24208],
#        [     38,   57902],
#        [    100, 1000000],
#        [    110, 1500000]])

# %%
scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(outliers_data)
# Out:
# StandardScaler()

# %%
scaled_ouliers_data=scaler.transform(outliers_data)
scaled_ouliers_data
# Out:
# array([[ 0.76750502, -0.18933355],
#        [ 0.51199759, -0.20811127],
#        [-1.12324998, -0.25449982],
#        [-1.17435147, -0.17979733],
#        [-0.40782917, -0.15562627],
#        [-1.32765593, -0.09729324],
#        [-0.66333661, -0.27168606],
#        [-1.22545296, -0.24428996],
#        [-1.27655444, -0.08792543],
#        [-0.20342323, -0.20008232],
#        [-1.0721485 , -0.09674591],
#        [ 1.07411394, -0.24378052],
#        [-0.25452471, -0.24626457],
#        [-0.86774255, -0.18019309],
#        [ 1.07411394, -0.20063807],
#        [ 1.17631691, -0.28624511],
#        [-0.76553958, -0.22735633],
#        [ 0.10318569, -0.1624553 ],
#        [-0.56113363, -0.2195421 ],
#        [-1.12324998, -0.22982354],
#        [-1.22545296, -0.25337147],
#        [ 0.30759164, -0.11161652],
#        [ 0.30759164, -0.12103485],
#        [-0.25452471, -0.13386349],
#        [ 0.76750502, -0.13092894],
#        [-0.91884404, -0.19633941],
#        [-1.22545296, -0.21262887],
#        [ 0.97191097, -0.2042631 ],
#        [ 0.56309907, -0.20761867],
#        [ 0.25649015, -0.19957709],
#        [ 0.81860651, -0.13019215],
#        [-0.71443809, -0.26451601],
#        [-1.22545296, -0.22984459],
#        [-0.40782917, -0.20998483],
#        [ 0.35869313, -0.12711024],
#        [ 1.12521543, -0.10011411],
#        [ 0.76750502, -0.24595722],
#        [-0.81664107, -0.17114526],
#        [ 1.12521543, -0.19230177],
#        [-1.02104701, -0.29183633],
#        [-0.51003215, -0.27516794],
#        [ 0.86970799, -0.15993336],
#        [ 0.40979461, -0.13388454],
#        [-0.51003215, -0.23264019],
#        [ 0.81860651, -0.1506245 ],
#        [ 0.15428718, -0.29204684],
#        [-0.20342323, -0.18412968],
#        [ 0.51199759, -0.213913  ],
#        [ 0.61420056, -0.2763426 ],
#        [-0.40782917, -0.13448239],
#        [ 2.760463  ,  3.83198702],
#        [ 3.27147786,  5.93711272]])

# %%
plt.subplot(1,2,1)
plt.scatter(outliers_data[:,0],outliers_data[:,1])
plt.title('before scaling')
plt.subplot(1,2,2)
plt.scatter(scaled_ouliers_data[:,0],scaled_ouliers_data[:,1])
plt.title('after scaling')
plt.show()

# %% [markdown]
# #outliers haru ootikai exist garxan standarization garda
# tara scale or kaam range ma na aauni vanae chai haina
# scale chai absolutely ghatxa ghatna chai
# tara aajhai pani para para nai hunxan
# value aajhai thulo xa aaru ko vanda outliers ko

# %%
#need of standarization

# %% [markdown]
# #need of standarization also for normalization
#
# slow convergence or no convergance:
#
#     as gradient descend algorithm also uses the features values .
#     so one feature being greater than another cause one parameter to
#     move slowly and other one to move hugely
#     as shown in fig
#
#     so  normalization or standarization is used when there is gradient descend used
#
#     mostly all the neural networks use gradient descend so you need to do either standarization or normalization

# %%
#using the gradient descend formula
from matplotlib.image import imread
image_path = "/content/gd.png"
image = imread(image_path)

# Display the image
plt.imshow(image)
plt.show()

# %% [markdown]
# #Normalization
# goal is same
# to bring dataset to common scales whithout distorting the difference in ranges or losing information
#
# normalization ma chai
#
#     (x-xmin)/(xmax-xmin)
#
# here all the data definitely lies between 0 and 1
# so it is like squishing data into a rectangle,cube ,hypercube according to the dimension

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(outliers_data)

# transform train and test sets
normalized_outliers_data = scaler.transform(outliers_data)

# %%
normalized_outliers_data
# Out:
# array([[4.55555556e-01, 1.64891093e-02],
#        [4.00000000e-01, 1.34746222e-02],
#        [4.44444444e-02, 6.02762243e-03],
#        [3.33333333e-02, 1.80200092e-02],
#        [2.00000000e-01, 2.19003165e-02],
#        [0.00000000e+00, 3.12648274e-02],
#        [1.44444444e-01, 3.26862324e-03],
#        [2.22222222e-02, 7.66666531e-03],
#        [1.11111111e-02, 3.27686915e-02],
#        [2.44444444e-01, 1.47635520e-02],
#        [5.55555556e-02, 3.13526936e-02],
#        [5.22222222e-01, 7.74844849e-03],
#        [2.33333333e-01, 7.34967104e-03],
#        [1.00000000e-01, 1.79564751e-02],
#        [5.22222222e-01, 1.46743340e-02],
#        [5.44444444e-01, 9.31381892e-04],
#        [1.22222222e-01, 1.03851109e-02],
#        [3.11111111e-01, 2.08040164e-02],
#        [1.66666667e-01, 1.16395701e-02],
#        [4.44444444e-02, 9.98903700e-03],
#        [2.22222222e-02, 6.20876202e-03],
#        [3.55555556e-01, 2.89654361e-02],
#        [3.55555556e-01, 2.74534613e-02],
#        [2.33333333e-01, 2.53940124e-02],
#        [4.55555556e-01, 2.58651105e-02],
#        [8.88888889e-02, 1.53644218e-02],
#        [2.22222222e-02, 1.27493880e-02],
#        [5.00000000e-01, 1.40923893e-02],
#        [4.11111111e-01, 1.35537018e-02],
#        [3.44444444e-01, 1.48446593e-02],
#        [4.66666667e-01, 2.59833919e-02],
#        [1.33333333e-01, 4.41967068e-03],
#        [2.22222222e-02, 9.98565753e-03],
#        [2.00000000e-01, 1.31738494e-02],
#        [3.66666667e-01, 2.64781463e-02],
#        [5.33333333e-01, 3.08119785e-02],
#        [4.55555556e-01, 7.39901130e-03],
#        [1.11111111e-01, 1.94089713e-02],
#        [5.33333333e-01, 1.60126041e-02],
#        [6.66666667e-02, 3.37946986e-05],
#        [1.77777778e-01, 2.70965893e-03],
#        [4.77777778e-01, 2.12088769e-02],
#        [3.77777778e-01, 2.53906329e-02],
#        [1.77777778e-01, 9.53686393e-03],
#        [4.66666667e-01, 2.27032785e-02],
#        [3.22222222e-01, 0.00000000e+00],
#        [2.44444444e-01, 1.73245143e-02],
#        [4.00000000e-01, 1.25432403e-02],
#        [4.22222222e-01, 2.52108451e-03],
#        [2.00000000e-01, 2.52946560e-02],
#        [8.88888889e-01, 6.62053014e-01],
#        [1.00000000e+00, 1.00000000e+00]])

# %%
plt.subplot(1,2,1)
plt.scatter(outliers_data[:,0],outliers_data[:,1])
plt.title('before normalization')
plt.subplot(1,2,2)
plt.scatter(normalized_outliers_data[:,0],normalized_outliers_data[:,1])
plt.title('after normalization')
plt.show()

# %%
#so maximum 1 vanda bhayek katai pani jadaina

# %% [markdown]
# #when to use which?
#
# image processing ma CNN ko kaam garda normalization use hunxa
# so if you know the value of the quantity lies within a box then use this
# in image processing values are between 0-255 so we already know the values lies within this box so we use normalization
#
# so when you have no idea use standard scaling
#
# so for img processing-CNN use normalization
# for other tasks use standarization
